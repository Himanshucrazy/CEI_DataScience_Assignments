# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
# 🤖 AGENT FUNCTION (TO IMPLEMENT)

def agent(query: str):
    query_lower = query.lower()

    try:

        # Route to Calculator Tool
        if "calculate" in query_lower:

            expression = query_lower.replace("calculate", "").strip()

            return {
                "type": "calculation",
                "result": calculator(expression)
            }

        # Route to Keyword Extractor
        elif "keywords" in query_lower:

            text = query.replace("Extract keywords from", "").replace("extract keywords from", "").strip()

            return {
                "type": "keywords",
                "result": extract_keywords(text)
            }

        # Route to General Response
        else:

            return {
                "type": "general",
                "result": "This is a general query. No tool was required."
            }

    except Exception:

        return {
            "type": "error",
            "result": "Something went wrong."
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['transforming', 'artificial', 'intelligence', 'industries']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': 'This is a general query. No tool was required.'}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): Calculate 100 + 25
# Response: {'type': 'calculation', 'result': '125'}
# Enter query (type 'exit' to stop): 10+10
# Response: {'type': 'general', 'result': 'This is a general query. No tool was required.'}
# Enter query (type 'exit' to stop): Extract keywords from Machine Learning is transforming healthcare and education
# Response: {'type': 'keywords', 'result': ['healthcare', 'machine', 'learning', 'education', 'transforming']}
# Enter query (type 'exit' to stop): What is machine learning?
# Response: {'type': 'general', 'result': 'This is a general query. No tool was required.'}
# Enter query (type 'exit' to stop): exit

# %% [markdown]
# ## 📌 Conclusion
#
# In this assignment, a Single-Agent Smart Assistant was successfully implemented using conditional routing. The agent identifies the user's intent and routes queries to the appropriate tool. Mathematical expressions are handled by the Calculator Tool, keyword extraction requests are processed by the Keyword Extractor Tool, and all other queries receive a structured general response. The implementation also includes basic error handling and returns results in a consistent JSON format, demonstrating a simple and effective single-agent pipeline.
